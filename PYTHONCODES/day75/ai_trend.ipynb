# %% [markdown]
# # imort libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # import data set

# %%
df = pd.read_csv('./AI_trend.csv')
df.Time = pd.to_datetime(df.Time)

# %%
df.head()
# Out:
#         Time  AI
# 0 2009-12-01   0
# 1 2010-01-01   0
# 2 2010-02-01   0
# 3 2010-03-01  10
# 4 2010-04-01   0

# %% [markdown]
# # Visualize line plot

# %%
plt.plot(df.Time , df.AI)
