# %% [markdown]
# # day 2 tip per persion calculator

# %%
bill = int(input("How much is the total bill $ " ))
tip = int(input("How much tip you wanna pay $ (10 , 15 , 20 , 25)  " ))
persons = int(input("How many people to pay ?" ))
total_bill = tip+bill
bill_per_person = total_bill / persons
print(" Total bill is " , total_bill,"\nEach person needs to pay $ " , bill_per_person)
# Out:
#  Each person needs to pay $  204.0

# %% [markdown]
# # Day 4 Randomization

# %%
# Rock paper scissors

# %%
import random
import os

choices = ['Rock' , 'Paper' , 'Scissors']

ascii_arts = {

'Rock' : """"
     (_______________)
----'(_______________)     
-----(______________)
-----(____________)
------(__________)
"""


}

def playagain():
    while(True):
        choice = input('Do you want to play again? (y or n)').lower()
        if choice=='y':
            return True
        elif choice == 'n':
            return False
        else:
            print ('Invalid Choice')


while(True):
    os.system('clear')
    playerchoice  = int(input('What do you want to choose? (O:Rock , 1:Paper , 2:Scissors) : '))
    playerchoice = choices[playerchoice]
    print('You choose ' , playerchoice)
    computerchoice = random.choice(choices)
    print('Computer choose' , computerchoice)

    if playerchoice == computerchoice:
       print('It\'s a draw ')
    elif (playerchoice == "Rock") and (computerchoice == "Paper"):
        print('You loose')
    elif (playerchoice == "Paper") and (computerchoice == "Scissors"):
        print('You loose')
    elif (playerchoice == "Scissors") and (computerchoice == "Rock"):
        print('You loose')
    else:
        print('You win')
    if playagain():
        continue
    else:
        break
# Out:
# You choose  Rock
# Computer choose Rock
# It's a draw
# Invalid Choice
# You choose  Rock
# Computer choose Paper
# You loose
# Invalid Choice
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 35
#      33 else:
#      34     print('You win')
# ---> 35 if playagain():
#      36     continue
#      37 else:
#
# Cell In[20], line 8, in playagain()
#       6 def playagain():
#       7     while(True):
# ----> 8         choice = input('Do you want to play again? (y or n)').lower()
#       9         if choice=='y':
#      10             return True
#
# File ~/.conda/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~/.conda/envs/ml/lib/python3.10/site-packages/ipykernel/kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
